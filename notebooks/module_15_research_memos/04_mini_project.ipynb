# %% [markdown]
# # Module 15 — Notebook 4: Mini Project — Write a Full Research Memo
#
# ## Learning Objectives
#
# By the end of this notebook, you will have:
#
# - Written a complete 5-section research memo as structured Python data
# - Reported results with baseline comparisons
# - Written for two different audiences: technical and non-technical
#
# This is the **final notebook of the full curriculum**.

# %% [markdown]
# ## Why This Matters for AI Research Engineering
#
# Every analysis you do ends in communication. A dataset exploration, a classifier evaluation, an error analysis — none of it matters until it reaches the person who can act on it.
#
# A research memo is that bridge. In this mini project, you will write a memo about the Module 12 classifier evaluation, structured as Python data. That makes it automatable: you could generate the prose sections, render them to a report, or diff memo versions in git.
#
# This is the kind of practical, reproducible research communication that AI safety labs depend on.

# %%
import sys
sys.path.insert(0, "../../")
from src.checks import check_equal, check_type, check_contains, check_keys, check_length

# Module 12 results — pre-filled for reference
RESULTS = {
    'v1_precision': 1.0,
    'v1_recall': 0.7143,
    'v1_f1': 0.8333,
    'v2_precision': 0.8571,
    'v2_recall': 0.8571,
    'v2_f1': 0.8571,
    'baseline_f1': 0.0,
    'total_outputs': 20,
    'total_flagged': 7,
    'recommended_classifier': 'v2'
}
print("Module 12 results loaded. Building the memo...")

# %% [markdown]
# ## Step 1 — Build the Memo
#
# Create a dict called `memo` with these 5 keys, all set to strings:
#
# - `'question'` — what question does this evaluation answer?
# - `'method'` — how was the evaluation conducted?
# - `'results'` — what were the findings, with numbers and comparisons?
# - `'caveats'` — what limitations should the reader know?
# - `'next_steps'` — what should happen next?
#
# Use the `RESULTS` dict above for the actual numbers. The `'results'` field must be at least 30 characters and describe what was found.

# %%
# YOUR CODE HERE
memo = {
    'question': '',
    'method': '',
    'results': '',
    'caveats': '',
    'next_steps': ''
}

# %%
check_keys(memo, ['question', 'method', 'results', 'caveats', 'next_steps'], "memo has all 5 sections")
check_type(memo['question'], str, "question is a string")
check_type(memo['results'], str, "results is a string")
check_equal(len(memo['results']) > 30, True, "results section is substantive")

# %% [markdown]
# ## Step 2 — Reference the Recommended Classifier
#
# The results section should name the recommended classifier. Make sure `memo['results']` contains the string `'v2'`.

# %%
# Update memo['results'] if needed so it mentions 'v2'
# memo['results'] = "..."

# %%
check_contains(memo['results'], 'v2', "results section references v2")

# %% [markdown]
# ## Step 3 — Substantive Caveats and Next Steps
#
# Verify that your `'caveats'` and `'next_steps'` sections are substantive (at least 20 characters each).
#
# If they are still empty from Step 1, fill them in now.

# %%
# Update memo['caveats'] and memo['next_steps'] if needed
# memo['caveats'] = "..."
# memo['next_steps'] = "..."

# %%
check_equal(len(memo['caveats']) >= 20, True, "caveats section is substantive")
check_equal(len(memo['next_steps']) >= 20, True, "next_steps section is substantive")

# %% [markdown]
# ## Step 4 — Write for Two Audiences
#
# Create a dict called `audience_versions` with two keys:
#
# - `'technical'` — a one-paragraph summary for a fellow ML engineer or researcher (can use terms like F1, precision, recall, classifier)
# - `'nontechnical'` — a one-paragraph summary for a product manager or policy stakeholder (explain what the system does and what the numbers mean in plain language)
#
# Both must be at least 20 characters.

# %%
# YOUR CODE HERE
audience_versions = {
    'technical': '',
    'nontechnical': ''
}

# %%
check_keys(audience_versions, ['technical', 'nontechnical'], "audience_versions has both keys")
check_type(audience_versions['technical'], str, "technical version is a string")
check_type(audience_versions['nontechnical'], str, "nontechnical version is a string")
check_equal(len(audience_versions['technical']) >= 20, True, "technical version is substantive")
check_equal(len(audience_versions['nontechnical']) >= 20, True, "nontechnical version is substantive")

# %% [markdown]
# ## Congratulations!
#
# You've completed the full curriculum. You've gone from Python beginner to someone who can:
# - Write, debug, and test Python analysis code
# - Load and analyze model outputs at scale
# - Build and evaluate safety classifiers
# - Communicate findings clearly to colleagues
#
# That's the core skill set of an AI research engineer. Keep building on it.
